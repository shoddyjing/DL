# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img_dir='../dataset/8.120206.jpg'
img=imread(img_dir)
plt.imshow(img)
plt.show()
#waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-928c8c66a11a> in <module>
#       6 plt.imshow(img)
#       7 plt.show()
# ----> 8 waitKey(0)
#
# NameError: name 'waitKey' is not defined
